# %%
import scipy.stats
import matplotlib.image as mpimg
from preprocessing.Optimal_crop import optimal_crop
import datetime
from dateutil.relativedelta import relativedelta

import numpy as np
from numpy.random import randint, random
import scipy.stats
import cv2

import matplotlib.pyplot as plt

# %%
# input fllename >> output 3d array
def read_img(filename, mode, size):
    if mode == 'RGB':
        img_3d = mpimg.imread(filename)
    elif mode == 'L':
        img_3d = mpimg.imread(filename)
    # Downsample the image
    small = cv2.resize(img_3d, (0, 0), fx = size[0], fy = size[1])
    # Blurring effect to denoise
    blur = cv2.blur(small, (4, 4))
    return blur


# input 3d array >> output 2d array
def flatten_img(img_3d, mode):
    if mode == 'RGB':
        x, y, z = img_3d.shape
        img_2d = img_3d.reshape(x*y, z)
        img_2d = np.array(img_2d, dtype = np.float64)
    elif mode == 'L':
        x, y = img_3d.shape
        img_2d = img_3d.reshape(x*y, 1)
        img_2d = np.array(img_2d, dtype = np.float64)
    return img_2d


# input 2d array >> output 3d array
def recover_img(img_2d, X, Y, mode = 'RGB', vis = False):
    #img_2d = cv2.resize(img_2d, (0, 0), fx=10, fy=10)
    if mode == 'RGB':
        img_2d = (img_2d * 255).astype(np.uint8)
        recover_img = img_2d.reshape(X, Y, 3)
    elif mode == 'L':
        recover_img = img_2d.reshape(X, Y)
    return recover_img


def random_init(img, k):
    # For gray-scale
    if len(img.shape) == 1:
        means = randint(low = 0, high = 255, size = (k,1))
        cov = randint(low = 0, high = 500, size = k)
        pis = random(size = k)
    else:
        z = img.shape[1]
        means = randint(low = 0, high = 255, size = (k , z))
        cov = randint(low = 0, high = 500, size = (k, z, z))
        pis = random(size = k)
    return means, cov, pis


# E-Step: Update Parameters
# update the conditional pdf - prob that pixel i given class j
def update_responsibility(img, means, cov, pis, k):
    # responsibilities: i th pixels, j th class
    # pis * gaussian.pdf
    responsibilities = np.array([pis[j] * scipy.stats.multivariate_normal.pdf(img, mean=means[j], cov=cov[j]) for j in range(k)]).T
    # normalize for each row
    norm = np.sum(responsibilities, axis = 1)
    # convert to column vector
    norm = np.reshape(norm, (len(norm), 1))
    responsibilities = responsibilities / norm
    return responsibilities


# update pi for each class of Gaussian model
def update_pis(responsibilities):
    pis = np.sum(responsibilities, axis = 0) / responsibilities.shape[0]
    return pis

# update means for each class of Gaussian model
def update_means(img, responsibilities):
    means = []
    class_n = responsibilities.shape[1]
    for j in range(class_n):
        weight = responsibilities[:, j] / np.sum(responsibilities[:, j])
        weight = np.reshape(weight, (1, len(weight)))
        means_j = weight.dot(img)
        means.append(means_j[0])
    means = np.array(means)
    return means

# update covariance matrix for each class of Gaussian model
def update_covariance(img, responsibilities, means):
    cov = []
    class_n = responsibilities.shape[1]
    for j in range(class_n):
        weight = responsibilities[:, j] / np.sum(responsibilities[:, j])
        weight = np.reshape(weight, (1, len(weight)))
        # Each pixels have a covariance matrice
        covs = [np.mat(i - means[j]).T * np.mat(i - means[j]) for i in img]
        # Weighted sum of covariance matrices
        cov_j = sum(weight[0][i] * covs[i] for i in range(len(weight[0])))
        cov.append(cov_j)
    cov = np.array(cov)
    return cov


# M-step: choose a label that maximise the likelihood
def update_labels(responsibilities):
    labels = np.argmax(responsibilities, axis = 1)
    return labels


def update_loglikelihood(img, means, cov, pis, k):
    pdf = np.array([pis[j] * scipy.stats.multivariate_normal.pdf(img, mean=means[j], cov=cov[j]) for j in range(k)])
    log_ll = np.log(np.sum(pdf, axis = 0))
    log_ll_sum = np.sum(log_ll)
    return log_ll_sum


def EM_cluster(img, k, random = False, error = 10e-3, iter_n = 1000):
    #  init setting
    cnt = 0
    likelihood_arr = []
    means_arr = []
    if random:
        means, cov, pis = random_init(img, k)
    likelihood = 0
    new_likelihood = 2
    means_arr.append(means)
    responsibilities = update_responsibility(img, means, cov, pis, k)
    while (abs(likelihood - new_likelihood) > error) and (cnt != iter_n):
        start_dt = datetime.datetime.now()
        cnt += 1
        likelihood = new_likelihood
        # M-Step
        labels = update_labels(responsibilities)
        # E-step
        responsibilities = update_responsibility(img, means, cov, pis, k)
        means = update_means(img, responsibilities)
        cov = update_covariance(img, responsibilities, means)
        pis = update_pis(responsibilities)
        new_likelihood = update_loglikelihood(img, means, cov, pis, k)
        likelihood_arr.append(new_likelihood)
        end_dt = datetime.datetime.now()
        diff = relativedelta(end_dt, start_dt)
        print("iter: %s, time interval: %s:%s:%s:%s" % (cnt, diff.hours, diff.minutes, diff.seconds, diff.microseconds))
        print("log-likelihood = {}".format(new_likelihood))
        # Store means stat
        means_arr.append(means)
    likelihood_arr = np.array(likelihood_arr)
    print('Converge at iteration {}'.format(cnt + 1))
    return labels, means, cov, pis, likelihood_arr, means_arr

# %%
def get_pdf(y, means, cov, pis, k):
    pdf_arr = np.array([pis[j] * scipy.stats.multivariate_normal.pdf(y, mean=means[j], cov=cov[j]) for j in range(k)])
    pdf = np.sum(pdf_arr)
    return pdf

# %%
FILENAME_LIST = [r'C:\Users\Asus\Desktop\PCD\Organized dataset\images\P_00001\LEFT_CC_1\cropped.jpg',r'C:\Users\Asus\Desktop\PCD\Organized dataset\images\P_00001\LEFT_MLO_1\cropped.jpg',r'C:\Users\Asus\Desktop\PCD\Organized dataset\images\P_00004\LEFT_CC_1\cropped.jpg']

# %%
# Visualize demo images
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15,15))
ax_list = [ax1, ax2, ax3]
gray_img_list = []
dim_img_list = []
i = 1
for filename, ax in zip(FILENAME_LIST, ax_list):
    gray_img = read_img(filename = filename, mode = 'L', size = (0.5, 0.5))
    x, y = gray_img.shape
    # Store dimension for each image
    dim_img_list.append((x,y))
    # Store img
    gray_img_list.append(gray_img)
    ax.imshow(gray_img, cmap = 'gray')
    ax.set_title('[Image {}] Original Image'.format(i))
    ax.axes.set_xlabel('x-coordinate')
    ax.axes.set_ylabel('y-coordinate')
    i += 1

plt.tight_layout()
fig.savefig('orig_images.pdf')

# %%
img_list = [flatten_img(image, mode = 'L') for image in gray_img_list]

# %%
image = mpimg.imread(r'C:\Users\Asus\Desktop\PCD\test_sample.jpg')
ROI = optimal_crop(image)
plt.imshow(ROI, cmap='gray')
plt.savefig(r'C:\Users\Asus\Desktop\PCD\ROI.jpg')
cv2.imwrite(r'C:\Users\Asus\Desktop\PCD\ROI_1.jpg',ROI)
# Out:
# True

# %%
# Init container
rand_likelihood_arr_list = []
rand_means_arr_list = []
rand_cov_arr_list = []
rand_pis_arr_list = []
rand_em_img_list = []
rand_means_list = []
for img, dim in zip(img_list, dim_img_list):
    labels, means, cov, pis, likelihood_arr, means_arr = EM_cluster(img, 3, random = True, error = 0.01)
    means = np.array([element[0] for element in means])
    cov = [element[0][0] for element in cov]
    em_img = means[labels]
    recover_img = em_img.reshape(dim[0], dim[1])
    # store required stat
    rand_likelihood_arr_list.append(likelihood_arr)
    rand_means_arr_list.append(means_arr)
    rand_cov_arr_list.append(cov)
    rand_pis_arr_list.append(pis)
    rand_em_img_list.append(recover_img)
    rand_means_list.append(means)
# Out:
# iter: 1, time interval: 0:0:4:411629
# log-likelihood = -285640.09608076414
# iter: 2, time interval: 0:0:3:794811
# log-likelihood = -285393.2184032325
# iter: 3, time interval: 0:0:3:771914
# log-likelihood = -285228.57094500645
# iter: 4, time interval: 0:0:3:794256
# log-likelihood = -285081.79339480307
# iter: 5, time interval: 0:0:3:810173
# log-likelihood = -284962.9078460022
# iter: 6, time interval: 0:0:3:794402
# log-likelihood = -284877.76958776923
# iter: 7, time interval: 0:0:3:879353
# log-likelihood = -284823.1784123454
# iter: 8, time interval: 0:0:3:810106
# log-likelihood = -284790.78648502304
# iter: 9, time interval: 0:0:3:809709
# log-likelihood = -284772.08403996885
# iter: 10, time interval: 0:0:3:771854
# log-likelihood = -284760.8927212247
# iter: 11, time interval: 0:0:3:826201
# log-likelihood = -284753.5304126751
# iter: 12, time interval: 0:0:3:810276
# log-likelihood = -284748.0632540149
# iter: 13, time interval: 0:0:3:794042
# log-likelihood = -284743.55404561
# iter: 14, time interval: 0:0:3:809890
# log-likelihood = -284739.5687300163
# iter: 15, time interval: 0:0:3:808871
# log-likelihood = -284735.9089294931
# iter: 16, time interval: 0:0:3:762931
# log-likelihood = -284732.48192140285
# iter: 17, time interval: 0:0:3:810040
# log-likelihood = -284729.24141516467
# iter: 18, time interval: 0:0:3:788297
# log-likelihood = -284726.16158571653
# iter: 19, time interval: 0:0:3:809614
# log-likelihood = -284723.2259003769
# iter: 20, time interval: 0:0:3:762788
# log-likelihood = -284720.422322185
# iter: 21, time interval: 0:0:3:825429
# log-likelihood = -284717.7412186808
# iter: 22, time interval: 0:0:3:763973
# log-likelihood = -284715.17441497865
# iter: 23, time interval: 0:0:3:872526
# log-likelihood = -284712.71473548707
# iter: 24, time interval: 0:0:3:825530
# log-likelihood = -284710.35575959756
# iter: 25, time interval: 0:0:3:931212
# log-likelihood = -284708.0916754448
# iter: 26, time interval: 0:0:4:257102
# log-likelihood = -284705.91718192486
# iter: 27, time interval: 0:0:4:263917
# log-likelihood = -284703.82741684036
# iter: 28, time interval: 0:0:4:281353
# log-likelihood = -284701.8179008117
# iter: 29, time interval: 0:0:4:224754
# log-likelihood = -284699.884491725
# iter: 30, time interval: 0:0:4:95032
# log-likelihood = -284698.02334682515
# iter: 31, time interval: 0:0:4:335903
# log-likelihood = -284696.2308906799
# iter: 32, time interval: 0:0:4:625303
# log-likelihood = -284694.50378782616
# iter: 33, time interval: 0:0:4:607562
# log-likelihood = -284692.8389192405
# iter: 34, time interval: 0:0:4:875722
# log-likelihood = -284691.23336197576
# iter: 35, time interval: 0:0:4:517367
# log-likelihood = -284689.6843714508
# iter: 36, time interval: 0:0:4:424976
# log-likelihood = -284688.1893659743
# iter: 37, time interval: 0:0:4:474696
# log-likelihood = -284686.74591316027
# iter: 38, time interval: 0:0:4:350744
# log-likelihood = -284685.3517179536
# iter: 39, time interval: 0:0:4:41645
# log-likelihood = -284684.0046120274
# iter: 40, time interval: 0:0:4:693370
# log-likelihood = -284682.70254435623
# iter: 41, time interval: 0:0:4:804451
# log-likelihood = -284681.4435727973
# iter: 42, time interval: 0:0:5:601575
# log-likelihood = -284680.2258565413
# iter: 43, time interval: 0:0:5:487855
# log-likelihood = -284679.0476493127
# iter: 44, time interval: 0:0:5:733466
# log-likelihood = -284677.9072932212
# iter: 45, time interval: 0:0:5:113368
# log-likelihood = -284676.80321317824
# iter: 46, time interval: 0:0:5:524237
# log-likelihood = -284675.73391180823
# iter: 47, time interval: 0:0:5:484757
# log-likelihood = -284674.69796479144
# iter: 48, time interval: 0:0:5:906215
# log-likelihood = -284673.6940165886
# iter: 49, time interval: 0:0:6:522568
# log-likelihood = -284672.72077650094
# iter: 50, time interval: 0:0:8:203078
# log-likelihood = -284671.7770150297
# iter: 51, time interval: 0:0:9:344028
# log-likelihood = -284670.8615605006
# iter: 52, time interval: 0:0:5:924165
# log-likelihood = -284669.9732959272
# iter: 53, time interval: 0:0:5:378466
# log-likelihood = -284669.11115608783
# iter: 54, time interval: 0:0:4:675484
# log-likelihood = -284668.2741247956
# iter: 55, time interval: 0:0:4:405582
# log-likelihood = -284667.4612323439
# iter: 56, time interval: 0:0:4:376839
# log-likelihood = -284666.6715531117
# iter: 57, time interval: 0:0:4:438380
# log-likelihood = -284665.90420331375
# iter: 58, time interval: 0:0:5:454810
# log-likelihood = -284665.1583388856
# iter: 59, time interval: 0:0:5:725369
# log-likelihood = -284664.43315349077
# iter: 60, time interval: 0:0:6:318343
# log-likelihood = -284663.7278766425
# iter: 61, time interval: 0:0:4:626148
# log-likelihood = -284663.0417719311
# iter: 62, time interval: 0:0:5:730358
# log-likelihood = -284662.37413534784
# iter: 63, time interval: 0:0:6:363329
# log-likelihood = -284661.72429370193
# iter: 64, time interval: 0:0:5:389486
# log-likelihood = -284661.0916031218
# iter: 65, time interval: 0:0:5:610584
# log-likelihood = -284660.4754476359
# iter: 66, time interval: 0:0:6:441872
# log-likelihood = -284659.8752378292
# iter: 67, time interval: 0:0:6:574255
# log-likelihood = -284659.29040956893
# iter: 68, time interval: 0:0:8:362213
# log-likelihood = -284658.7204227971
# iter: 69, time interval: 0:0:7:807390
# log-likelihood = -284658.16476038465
# iter: 70, time interval: 0:0:6:648455
# log-likelihood = -284657.62292704516
# iter: 71, time interval: 0:0:7:10057
# log-likelihood = -284657.09444830264
# iter: 72, time interval: 0:0:6:258712
# log-likelihood = -284656.57886951265
# iter: 73, time interval: 0:0:7:313850
# log-likelihood = -284656.07575493254
# iter: 74, time interval: 0:0:6:533535
# log-likelihood = -284655.58468683803
# iter: 75, time interval: 0:0:6:786771
# log-likelihood = -284655.10526468494
# iter: 76, time interval: 0:0:7:615354
# log-likelihood = -284654.6371043117
# iter: 77, time interval: 0:0:6:934618
# log-likelihood = -284654.17983718263
# iter: 78, time interval: 0:0:7:545384
# log-likelihood = -284653.7331096679
# iter: 79, time interval: 0:0:7:285696
# log-likelihood = -284653.29658236005
# iter: 80, time interval: 0:0:7:552779
# log-likelihood = -284652.8699294236
# iter: 81, time interval: 0:0:8:185713
# log-likelihood = -284652.45283797686
# iter: 82, time interval: 0:0:7:68754
# log-likelihood = -284652.0450075044
# iter: 83, time interval: 0:0:6:378404
# log-likelihood = -284651.6461492983
# iter: 84, time interval: 0:0:6:123818
# log-likelihood = -284651.2559859266
# iter: 85, time interval: 0:0:5:211562
# log-likelihood = -284650.8742507276
# iter: 86, time interval: 0:0:7:184970
# log-likelihood = -284650.50068732945
# iter: 87, time interval: 0:0:6:295807
# log-likelihood = -284650.1350491923
# iter: 88, time interval: 0:0:5:884120
# log-likelihood = -284649.777099173
# iter: 89, time interval: 0:0:7:188946
# log-likelihood = -284649.4266091112
# iter: 90, time interval: 0:0:6:852500
# log-likelihood = -284649.0833594349
# iter: 91, time interval: 0:0:7:770408
# log-likelihood = -284648.7471387852
# iter: 92, time interval: 0:0:9:355654
# log-likelihood = -284648.41774365905
# iter: 93, time interval: 0:0:11:654260
# log-likelihood = -284648.0949780695
# iter: 94, time interval: 0:0:12:188217
# log-likelihood = -284647.778653221
# iter: 95, time interval: 0:0:12:489638
# log-likelihood = -284647.46858720185
# iter: 96, time interval: 0:0:12:721725
# log-likelihood = -284647.16460468987
# iter: 97, time interval: 0:0:11:926267
# log-likelihood = -284646.86653667246
# iter: 98, time interval: 0:0:12:774871
# log-likelihood = -284646.57422018016
# iter: 99, time interval: 0:0:12:901979
# log-likelihood = -284646.2874980322
# iter: 100, time interval: 0:0:12:945295
# log-likelihood = -284646.0062185945
# iter: 101, time interval: 0:0:13:400409
# log-likelihood = -284645.73023554834
# iter: 102, time interval: 0:0:14:223163
# log-likelihood = -284645.4594076705
# iter: 103, time interval: 0:0:15:477295
# log-likelihood = -284645.1935986231
# iter: 104, time interval: 0:0:13:836848
# log-likelihood = -284644.9326767534
# iter: 105, time interval: 0:0:12:21748
# log-likelihood = -284644.67651490244
# iter: 106, time interval: 0:0:13:183218
# log-likelihood = -284644.42499022326
# iter: 107, time interval: 0:0:12:161403
# log-likelihood = -284644.1779840061
# iter: 108, time interval: 0:0:11:989595
# log-likelihood = -284643.93538151344
# iter: 109, time interval: 0:0:17:630797
# log-likelihood = -284643.69707182015
# iter: 110, time interval: 0:0:15:572792
# log-likelihood = -284643.4629476632
# iter: 111, time interval: 0:0:13:875375
# log-likelihood = -284643.23290529626
# iter: 112, time interval: 0:0:14:636194
# log-likelihood = -284643.00684435223
# iter: 113, time interval: 0:0:16:995809
# log-likelihood = -284642.78466771054
# iter: 114, time interval: 0:0:18:451044
# log-likelihood = -284642.56628137175
# iter: 115, time interval: 0:0:13:330247
# log-likelihood = -284642.3515943366
# iter: 116, time interval: 0:0:12:776596
# log-likelihood = -284642.1405184908
# iter: 117, time interval: 0:0:13:126433
# log-likelihood = -284641.9329684948
# iter: 118, time interval: 0:0:14:638292
# log-likelihood = -284641.7288616784
# iter: 119, time interval: 0:0:16:227261
# log-likelihood = -284641.52811794024
# iter: 120, time interval: 0:0:12:238495
# log-likelihood = -284641.3306596506
# iter: 121, time interval: 0:0:9:386925
# log-likelihood = -284641.13641156
# iter: 122, time interval: 0:0:9:589671
# log-likelihood = -284640.9453007098
# iter: 123, time interval: 0:0:12:969698
# log-likelihood = -284640.75725634844
# iter: 124, time interval: 0:0:11:939542
# log-likelihood = -284640.57220985007
# iter: 125, time interval: 0:0:11:238629
# log-likelihood = -284640.39009463665
# iter: 126, time interval: 0:0:9:971863
# log-likelihood = -284640.21084610414
# iter: 127, time interval: 0:0:9:238133
# log-likelihood = -284640.0344015507
# iter: 128, time interval: 0:0:10:51647
# log-likelihood = -284639.8607001091
# iter: 129, time interval: 0:0:11:124764
# log-likelihood = -284639.68968268024
# iter: 130, time interval: 0:0:13:724825
# log-likelihood = -284639.52129187144
# iter: 131, time interval: 0:0:10:506991
# log-likelihood = -284639.3554719353
# iter: 132, time interval: 0:0:10:73208
# log-likelihood = -284639.1921687128
# iter: 133, time interval: 0:0:10:525765
# log-likelihood = -284639.0313295772
# iter: 134, time interval: 0:0:12:106540
# log-likelihood = -284638.87290338136
# iter: 135, time interval: 0:0:9:903391
# log-likelihood = -284638.71684040624
# iter: 136, time interval: 0:0:7:294939
# log-likelihood = -284638.56309231237
# iter: 137, time interval: 0:0:7:232640
# log-likelihood = -284638.41161209246
# iter: 138, time interval: 0:0:8:74867
# log-likelihood = -284638.26235402626
# iter: 139, time interval: 0:0:9:404189
# log-likelihood = -284638.11527363735
# iter: 140, time interval: 0:0:9:949384
# log-likelihood = -284637.97032765124
# iter: 141, time interval: 0:0:15:150190
# log-likelihood = -284637.82747395535
# iter: 142, time interval: 0:0:13:924182
# log-likelihood = -284637.68667156034
# iter: 143, time interval: 0:0:14:67815
# log-likelihood = -284637.5478805632
# iter: 144, time interval: 0:0:16:455940
# log-likelihood = -284637.4110621117
# iter: 145, time interval: 0:0:15:27396
# log-likelihood = -284637.27617837
# iter: 146, time interval: 0:0:15:955902
# log-likelihood = -284637.14319248556
# iter: 147, time interval: 0:0:14:641503
# log-likelihood = -284637.0120685576
# iter: 148, time interval: 0:0:16:402442
# log-likelihood = -284636.8827716067
# iter: 149, time interval: 0:0:17:449209
# log-likelihood = -284636.75526754506
# iter: 150, time interval: 0:0:13:756400
# log-likelihood = -284636.62952314847
# iter: 151, time interval: 0:0:17:141074
# log-likelihood = -284636.505506029
# iter: 152, time interval: 0:0:12:968151
# log-likelihood = -284636.38318460865
# iter: 153, time interval: 0:0:12:957989
# log-likelihood = -284636.2625280943
# iter: 154, time interval: 0:0:10:318143
# log-likelihood = -284636.14350645314
# iter: 155, time interval: 0:0:8:339951
# log-likelihood = -284636.02609038935
# iter: 156, time interval: 0:0:8:467956
# log-likelihood = -284635.9102513214
# iter: 157, time interval: 0:0:7:696801
# log-likelihood = -284635.7959613601
# iter: 158, time interval: 0:0:8:315713
# log-likelihood = -284635.683193288
# iter: 159, time interval: 0:0:7:692505
# log-likelihood = -284635.5719205386
# iter: 160, time interval: 0:0:9:653895
# log-likelihood = -284635.4621171771
# iter: 161, time interval: 0:0:12:735225
# log-likelihood = -284635.35375788144
# iter: 162, time interval: 0:0:14:508854
# log-likelihood = -284635.24681792397
# iter: 163, time interval: 0:0:11:193091
# log-likelihood = -284635.1412731542
# iter: 164, time interval: 0:0:8:184113
# log-likelihood = -284635.03709998133
# iter: 165, time interval: 0:0:6:996058
# log-likelihood = -284634.93427535845
# iter: 166, time interval: 0:0:5:773406
# log-likelihood = -284634.83277676615
# iter: 167, time interval: 0:0:6:734493
# log-likelihood = -284634.7325821977
# iter: 168, time interval: 0:0:7:380209
# log-likelihood = -284634.633670144
# iter: 169, time interval: 0:0:7:293314
# log-likelihood = -284634.5360195796
# iter: 170, time interval: 0:0:6:866903
# log-likelihood = -284634.43960994855
# iter: 171, time interval: 0:0:6:522967
# log-likelihood = -284634.34442115127
# iter: 172, time interval: 0:0:7:80963
# log-likelihood = -284634.25043353194
# iter: 173, time interval: 0:0:7:215050
# log-likelihood = -284634.1576278654
# iter: 174, time interval: 0:0:8:94354
# log-likelihood = -284634.06598534604
# iter: 175, time interval: 0:0:6:653569
# log-likelihood = -284633.97548757517
# iter: 176, time interval: 0:0:6:206516
# log-likelihood = -284633.8861165506
# iter: 177, time interval: 0:0:6:266047
# log-likelihood = -284633.7978546552
# iter: 178, time interval: 0:0:8:681557
# log-likelihood = -284633.71068464644
# iter: 179, time interval: 0:0:7:719807
# log-likelihood = -284633.62458964676
# iter: 180, time interval: 0:0:6:747128
# log-likelihood = -284633.53955313284
# iter: 181, time interval: 0:0:6:692918
# log-likelihood = -284633.4555589267
# iter: 182, time interval: 0:0:6:930432
# log-likelihood = -284633.372591186
# iter: 183, time interval: 0:0:6:613167
# log-likelihood = -284633.29063439555
# iter: 184, time interval: 0:0:8:242465
# log-likelihood = -284633.2096733582
# iter: 185, time interval: 0:0:7:678681
# log-likelihood = -284633.1296931867
# iter: 186, time interval: 0:0:7:633679
# log-likelihood = -284633.0506792957
# iter: 187, time interval: 0:0:6:440791
# log-likelihood = -284632.9726173932
# iter: 188, time interval: 0:0:9:958540
# log-likelihood = -284632.8954934738
# iter: 189, time interval: 0:0:10:627495
# log-likelihood = -284632.81929381064
# iter: 190, time interval: 0:0:10:199283
# log-likelihood = -284632.74400494853
# iter: 191, time interval: 0:0:10:892576
# log-likelihood = -284632.6696136969
# iter: 192, time interval: 0:0:7:673249
# log-likelihood = -284632.5961071232
# iter: 193, time interval: 0:0:7:919582
# log-likelihood = -284632.52347254584
# iter: 194, time interval: 0:0:8:877741
# log-likelihood = -284632.4516975287
# iter: 195, time interval: 0:0:12:58957
# log-likelihood = -284632.3807698742
# iter: 196, time interval: 0:0:8:355824
# log-likelihood = -284632.3106776177
# iter: 197, time interval: 0:0:9:33309
# log-likelihood = -284632.24140902166
# iter: 198, time interval: 0:0:11:559505
# log-likelihood = -284632.17295257014
# iter: 199, time interval: 0:0:13:357221
# log-likelihood = -284632.1052969629
# iter: 200, time interval: 0:0:8:204217
# log-likelihood = -284632.0384311107
# iter: 201, time interval: 0:0:10:394849
# log-likelihood = -284631.97234412975
# iter: 202, time interval: 0:0:9:776368
# log-likelihood = -284631.90702533675
# iter: 203, time interval: 0:0:11:39876
# log-likelihood = -284631.84246424446
# iter: 204, time interval: 0:0:9:673021
# log-likelihood = -284631.77865055617
# iter: 205, time interval: 0:0:10:80216
# log-likelihood = -284631.7155741621
# iter: 206, time interval: 0:0:11:328067
# log-likelihood = -284631.6532251342
# iter: 207, time interval: 0:0:10:133888
# log-likelihood = -284631.5915937223
# iter: 208, time interval: 0:0:8:58941
# log-likelihood = -284631.53067034966
# iter: 209, time interval: 0:0:7:779393
# log-likelihood = -284631.47044560895
# iter: 210, time interval: 0:0:7:593827
# log-likelihood = -284631.4109102583
# iter: 211, time interval: 0:0:6:787365
# log-likelihood = -284631.3520552178
# iter: 212, time interval: 0:0:8:99123
# log-likelihood = -284631.2938715649
# iter: 213, time interval: 0:0:8:227309
# log-likelihood = -284631.23635053186
# iter: 214, time interval: 0:0:8:81994
# log-likelihood = -284631.17948350124
# iter: 215, time interval: 0:0:14:337271
# log-likelihood = -284631.1232620031
# iter: 216, time interval: 0:0:13:395030
# log-likelihood = -284631.0676777116
# iter: 217, time interval: 0:0:9:453740
# log-likelihood = -284631.0127224411
# iter: 218, time interval: 0:0:14:640754
# log-likelihood = -284630.95838814415
# iter: 219, time interval: 0:0:12:504858
# log-likelihood = -284630.9046669073
# iter: 220, time interval: 0:0:8:36623
# log-likelihood = -284630.8515509487
# iter: 221, time interval: 0:0:8:912366
# log-likelihood = -284630.79903261503
# iter: 222, time interval: 0:0:11:601212
# log-likelihood = -284630.7471043788
# iter: 223, time interval: 0:0:8:70016
# log-likelihood = -284630.69575883547
# iter: 224, time interval: 0:0:7:869315
# log-likelihood = -284630.6449887005
# iter: 225, time interval: 0:0:11:906495
# log-likelihood = -284630.5947868074
# iter: 226, time interval: 0:0:14:601903
# log-likelihood = -284630.54514610465
# iter: 227, time interval: 0:0:10:602498
# log-likelihood = -284630.49605965335
# iter: 228, time interval: 0:0:8:227495
# log-likelihood = -284630.44752062473
# iter: 229, time interval: 0:0:6:391085
# log-likelihood = -284630.3995222981
# iter: 230, time interval: 0:0:5:829120
# log-likelihood = -284630.3520580582
# iter: 231, time interval: 0:0:6:221316
# log-likelihood = -284630.3051213933
# iter: 232, time interval: 0:0:6:965925
# log-likelihood = -284630.2587058926
# iter: 233, time interval: 0:0:7:672634
# log-likelihood = -284630.2128052447
# iter: 234, time interval: 0:0:7:902401
# log-likelihood = -284630.16741323494
# iter: 235, time interval: 0:0:7:490557
# log-likelihood = -284630.1225237439
# iter: 236, time interval: 0:0:6:977442
# log-likelihood = -284630.0781307448
# iter: 237, time interval: 0:0:6:478042
# log-likelihood = -284630.03422830254
# iter: 238, time interval: 0:0:6:358008
# log-likelihood = -284629.99081057095
# iter: 239, time interval: 0:0:6:756747
# log-likelihood = -284629.9478717914
# iter: 240, time interval: 0:0:6:537505
# log-likelihood = -284629.90540629096
# iter: 241, time interval: 0:0:6:745595
# log-likelihood = -284629.86340848065
# iter: 242, time interval: 0:0:12:12963
# log-likelihood = -284629.8218728539
# iter: 243, time interval: 0:0:13:301361
# log-likelihood = -284629.78079398454
# iter: 244, time interval: 0:0:7:400818
# log-likelihood = -284629.7401665258
# iter: 245, time interval: 0:0:6:893660
# log-likelihood = -284629.6999852083
# iter: 246, time interval: 0:0:6:201027
# log-likelihood = -284629.66024483833
# iter: 247, time interval: 0:0:14:223592
# log-likelihood = -284629.620940297
# iter: 248, time interval: 0:0:8:818055
# log-likelihood = -284629.5820665385
# iter: 249, time interval: 0:0:9:665656
# log-likelihood = -284629.54361858853
# iter: 250, time interval: 0:0:14:241251
# log-likelihood = -284629.505591543
# iter: 251, time interval: 0:0:10:190811
# log-likelihood = -284629.4679805668
# iter: 252, time interval: 0:0:14:125963
# log-likelihood = -284629.4307808925
# iter: 253, time interval: 0:0:13:438932
# log-likelihood = -284629.39398781874
# iter: 254, time interval: 0:0:11:948730
# log-likelihood = -284629.3575967096
# iter: 255, time interval: 0:0:13:197154
# log-likelihood = -284629.3216029928
# iter: 256, time interval: 0:0:13:466566
# log-likelihood = -284629.2860021586
# iter: 257, time interval: 0:0:12:372409
# log-likelihood = -284629.250789759
# iter: 258, time interval: 0:0:11:547047
# log-likelihood = -284629.2159614063
# iter: 259, time interval: 0:0:10:700307
# log-likelihood = -284629.181512772
# iter: 260, time interval: 0:0:9:866171
# log-likelihood = -284629.1474395857
# iter: 261, time interval: 0:0:12:140426
# log-likelihood = -284629.11373763427
# iter: 262, time interval: 0:0:14:587266
# log-likelihood = -284629.08040276053
# iter: 263, time interval: 0:0:11:552865
# log-likelihood = -284629.04743086244
# iter: 264, time interval: 0:0:11:676093
# log-likelihood = -284629.0148178921
# iter: 265, time interval: 0:0:17:153983
# log-likelihood = -284628.98255985463
# iter: 266, time interval: 0:0:14:269749
# log-likelihood = -284628.95065280737
# iter: 267, time interval: 0:0:15:67858
# log-likelihood = -284628.9190928588
# iter: 268, time interval: 0:0:15:299547
# log-likelihood = -284628.887876168
# iter: 269, time interval: 0:0:8:352022
# log-likelihood = -284628.8569989433
# iter: 270, time interval: 0:0:8:354807
# log-likelihood = -284628.82645744184
# iter: 271, time interval: 0:0:7:615001
# log-likelihood = -284628.79624796845
# iter: 272, time interval: 0:0:8:90084
# log-likelihood = -284628.76636687486
# iter: 273, time interval: 0:0:8:983489
# log-likelihood = -284628.7368105591
# iter: 274, time interval: 0:0:8:904921
# log-likelihood = -284628.7075754645
# iter: 275, time interval: 0:0:16:844806
# log-likelihood = -284628.678658079
# iter: 276, time interval: 0:0:14:672225
# log-likelihood = -284628.6500549345
# iter: 277, time interval: 0:0:16:560633
# log-likelihood = -284628.62176260585
# iter: 278, time interval: 0:0:9:344373
# log-likelihood = -284628.59377771046
# iter: 279, time interval: 0:0:9:307249
# log-likelihood = -284628.5660969073
# iter: 280, time interval: 0:0:11:677044
# log-likelihood = -284628.53871689667
# iter: 281, time interval: 0:0:15:466595
# log-likelihood = -284628.51163441886
# iter: 282, time interval: 0:0:11:486084
# log-likelihood = -284628.48484625405
# iter: 283, time interval: 0:0:11:166687
# log-likelihood = -284628.4583492215
# iter: 284, time interval: 0:0:12:226214
# log-likelihood = -284628.43214017875
# iter: 285, time interval: 0:0:12:13391
# log-likelihood = -284628.4062160213
# iter: 286, time interval: 0:0:13:84008
# log-likelihood = -284628.3805736818
# iter: 287, time interval: 0:0:10:770524
# log-likelihood = -284628.3552101295
# iter: 288, time interval: 0:0:15:259730
# log-likelihood = -284628.3301223697
# iter: 289, time interval: 0:0:15:705788
# log-likelihood = -284628.3053074433
# iter: 290, time interval: 0:0:9:347506
# log-likelihood = -284628.280762426
# iter: 291, time interval: 0:0:10:263860
# log-likelihood = -284628.2564844277
# iter: 292, time interval: 0:0:12:615020
# log-likelihood = -284628.2324705926
# iter: 293, time interval: 0:0:13:607376
# log-likelihood = -284628.20871809794
# iter: 294, time interval: 0:0:12:505541
# log-likelihood = -284628.185224154
# iter: 295, time interval: 0:0:8:818445
# log-likelihood = -284628.161986003
# iter: 296, time interval: 0:0:7:552679
# log-likelihood = -284628.1390009195
# iter: 297, time interval: 0:0:7:953781
# log-likelihood = -284628.116266209
# iter: 298, time interval: 0:0:7:507486
# log-likelihood = -284628.09377920826
# iter: 299, time interval: 0:0:8:465215
# log-likelihood = -284628.0715372842
# iter: 300, time interval: 0:0:10:702538
# log-likelihood = -284628.049537834
# iter: 301, time interval: 0:0:12:270404
# log-likelihood = -284628.02777828416
# iter: 302, time interval: 0:0:11:343563
# log-likelihood = -284628.0062560905
# iter: 303, time interval: 0:0:10:334456
# log-likelihood = -284627.9849687373
# iter: 304, time interval: 0:0:11:733547
# log-likelihood = -284627.96391373745
# iter: 305, time interval: 0:0:16:645844
# log-likelihood = -284627.94308863155
# iter: 306, time interval: 0:0:7:142771
# log-likelihood = -284627.92249098764
# iter: 307, time interval: 0:0:6:29048
# log-likelihood = -284627.90211840096
# iter: 308, time interval: 0:0:6:808647
# log-likelihood = -284627.88196849346
# iter: 309, time interval: 0:0:7:910196
# log-likelihood = -284627.8620389134
# iter: 310, time interval: 0:0:7:521537
# log-likelihood = -284627.8423273351
# iter: 311, time interval: 0:0:6:692452
# log-likelihood = -284627.82283145835
# iter: 312, time interval: 0:0:6:891622
# log-likelihood = -284627.8035490083
# iter: 313, time interval: 0:0:7:458292
# log-likelihood = -284627.78447773505
# iter: 314, time interval: 0:0:7:378932
# log-likelihood = -284627.7656154132
# iter: 315, time interval: 0:0:6:685914
# log-likelihood = -284627.7469598417
# iter: 316, time interval: 0:0:7:116245
# log-likelihood = -284627.7285088433
# iter: 317, time interval: 0:0:7:825587
# log-likelihood = -284627.71026026446
# iter: 318, time interval: 0:0:7:420446
# log-likelihood = -284627.69221197476
# iter: 319, time interval: 0:0:5:769511
# log-likelihood = -284627.67436186713
# iter: 320, time interval: 0:0:5:430890
# log-likelihood = -284627.6567078567
# iter: 321, time interval: 0:0:4:968910
# log-likelihood = -284627.63924788125
# iter: 322, time interval: 0:0:6:409185
# log-likelihood = -284627.6219799006
# iter: 323, time interval: 0:0:6:413767
# log-likelihood = -284627.6049018963
# iter: 324, time interval: 0:0:8:15856
# log-likelihood = -284627.5880118717
# iter: 325, time interval: 0:0:6:452960
# log-likelihood = -284627.5713078509
# iter: 326, time interval: 0:0:7:489986
# log-likelihood = -284627.5547878794
# iter: 327, time interval: 0:0:7:425411
# log-likelihood = -284627.5384500233
# iter: 328, time interval: 0:0:5:452792
# log-likelihood = -284627.5222923689
# iter: 329, time interval: 0:0:6:343990
# log-likelihood = -284627.50631302304
# iter: 330, time interval: 0:0:5:18584
# log-likelihood = -284627.49051011243
# iter: 331, time interval: 0:0:5:888872
# log-likelihood = -284627.4748817831
# iter: 332, time interval: 0:0:6:593565
# log-likelihood = -284627.459426201
# iter: 333, time interval: 0:0:5:300136
# log-likelihood = -284627.44414155104
# iter: 334, time interval: 0:0:5:897942
# log-likelihood = -284627.42902603716
# iter: 335, time interval: 0:0:5:970618
# log-likelihood = -284627.414077882
# iter: 336, time interval: 0:0:4:799924
# log-likelihood = -284627.3992953267
# iter: 337, time interval: 0:0:5:842013
# log-likelihood = -284627.3846766308
# iter: 338, time interval: 0:0:8:727490
# log-likelihood = -284627.37022007175
# iter: 339, time interval: 0:0:8:138747
# log-likelihood = -284627.3559239451
# iter: 340, time interval: 0:0:9:884211
# log-likelihood = -284627.34178656375
# iter: 341, time interval: 0:0:7:175523
# log-likelihood = -284627.32780625817
# iter: 342, time interval: 0:0:6:289684
# log-likelihood = -284627.313981376
# iter: 343, time interval: 0:0:6:441849
# log-likelihood = -284627.30031028215
# iter: 344, time interval: 0:0:7:369772
# log-likelihood = -284627.286791358
# iter: 345, time interval: 0:0:7:170627
# log-likelihood = -284627.27342300187
# iter: 346, time interval: 0:0:6:777580
# log-likelihood = -284627.2602036283
# iter: 347, time interval: 0:0:5:501884
# log-likelihood = -284627.24713166815
# iter: 348, time interval: 0:0:6:504543
# log-likelihood = -284627.2342055685
# iter: 349, time interval: 0:0:6:650897
# log-likelihood = -284627.22142379207
# iter: 350, time interval: 0:0:8:363004
# log-likelihood = -284627.2087848174
# iter: 351, time interval: 0:0:8:402563
# log-likelihood = -284627.1962871386
# iter: 352, time interval: 0:0:8:235314
# log-likelihood = -284627.1839292652
# iter: 353, time interval: 0:0:9:900538
# log-likelihood = -284627.1717097216
# iter: 354, time interval: 0:0:7:839235
# log-likelihood = -284627.1596270476
# iter: 355, time interval: 0:0:8:176019
# log-likelihood = -284627.1476797975
# iter: 356, time interval: 0:0:11:160880
# log-likelihood = -284627.1358665406
# iter: 357, time interval: 0:0:11:994307
# log-likelihood = -284627.12418586045
# iter: 358, time interval: 0:0:11:545614
# log-likelihood = -284627.1126363552
# iter: 359, time interval: 0:0:11:406496
# log-likelihood = -284627.10121663706
# iter: 360, time interval: 0:0:11:187377
# log-likelihood = -284627.08992533234
# iter: 361, time interval: 0:0:12:741119
# log-likelihood = -284627.0787610812
# iter: 362, time interval: 0:0:12:854367
# log-likelihood = -284627.0677225376
# iter: 363, time interval: 0:0:11:753717
# log-likelihood = -284627.0568083691
# iter: 364, time interval: 0:0:10:185395
# log-likelihood = -284627.0460172567
# iter: 365, time interval: 0:0:12:507255
# log-likelihood = -284627.03534789477
# iter: 366, time interval: 0:0:11:375270
# log-likelihood = -284627.0247989908
# iter: 367, time interval: 0:0:8:770254
# log-likelihood = -284627.0143692653
# iter: 368, time interval: 0:0:9:883982
# log-likelihood = -284627.0040574517
# iter: 369, time interval: 0:0:12:583529
# log-likelihood = -284626.9938622962
# iter: 370, time interval: 0:0:11:342948
# log-likelihood = -284626.98378255765
# iter: 371, time interval: 0:0:12:870161
# log-likelihood = -284626.9738170075
# Converge at iteration 372
# iter: 1, time interval: 0:0:5:29865
# log-likelihood = -99553.6264765838
# iter: 2, time interval: 0:0:4:772483
# log-likelihood = -99388.39981623659
# iter: 3, time interval: 0:0:3:983666
# log-likelihood = -99301.79158794174
# iter: 4, time interval: 0:0:3:698179
# log-likelihood = -99233.62953973685
# iter: 5, time interval: 0:0:4:237364
# log-likelihood = -99170.97761781518
# iter: 6, time interval: 0:0:4:350213
# log-likelihood = -99109.07222647627
# iter: 7, time interval: 0:0:3:662947
# log-likelihood = -99046.00696391308
# iter: 8, time interval: 0:0:3:257353
# log-likelihood = -98981.36453010025
# iter: 9, time interval: 0:0:2:805522
# log-likelihood = -98915.7445881751
# iter: 10, time interval: 0:0:2:747588
# log-likelihood = -98850.40932692836
# iter: 11, time interval: 0:0:2:747605
# log-likelihood = -98786.85216234077
# iter: 12, time interval: 0:0:3:533759
# log-likelihood = -98726.38820899311
# iter: 13, time interval: 0:0:3:756320
# log-likelihood = -98669.91716444147
# iter: 14, time interval: 0:0:4:320523
# log-likelihood = -98617.90115863092
# iter: 15, time interval: 0:0:3:269032
# log-likelihood = -98570.48890441538
# iter: 16, time interval: 0:0:3:562143
# log-likelihood = -98527.68059679067
# iter: 17, time interval: 0:0:3:390696
# log-likelihood = -98489.44364911948
# iter: 18, time interval: 0:0:3:799021
# log-likelihood = -98455.73102445474
# iter: 19, time interval: 0:0:4:700501
# log-likelihood = -98426.41993406892
# iter: 20, time interval: 0:0:5:408340
# log-likelihood = -98401.24726767879
# iter: 21, time interval: 0:0:4:828056
# log-likelihood = -98379.80907834851
# iter: 22, time interval: 0:0:4:282200
# log-likelihood = -98361.62209301768
# iter: 23, time interval: 0:0:4:134699
# log-likelihood = -98346.19726857216
# iter: 24, time interval: 0:0:3:766869
# log-likelihood = -98333.08711951143
# iter: 25, time interval: 0:0:3:434558
# log-likelihood = -98321.90205051083
# iter: 26, time interval: 0:0:3:673018
# log-likelihood = -98312.30824790336
# iter: 27, time interval: 0:0:3:451524
# log-likelihood = -98304.01915306288
# iter: 28, time interval: 0:0:4:200209
# log-likelihood = -98296.78659002001
# iter: 29, time interval: 0:0:4:202434
# log-likelihood = -98290.39333504732
# iter: 30, time interval: 0:0:4:416069
# log-likelihood = -98284.64716236228
# iter: 31, time interval: 0:0:3:668633
# log-likelihood = -98279.3760712993
# iter: 32, time interval: 0:0:3:898801
# log-likelihood = -98274.42458183452
# iter: 33, time interval: 0:0:3:879009
# log-likelihood = -98269.65125558033
# iter: 34, time interval: 0:0:3:87299
# log-likelihood = -98264.92779852038
# iter: 35, time interval: 0:0:3:274816
# log-likelihood = -98260.14013277923
# iter: 36, time interval: 0:0:2:576513
# log-likelihood = -98255.19158613482
# iter: 37, time interval: 0:0:2:931286
# log-likelihood = -98250.00778930423
# iter: 38, time interval: 0:0:4:69540
# log-likelihood = -98244.54212103723
# iter: 39, time interval: 0:0:4:636061
# log-likelihood = -98238.77996802589
# iter: 40, time interval: 0:0:3:668371
# log-likelihood = -98232.74009791367
# iter: 41, time interval: 0:0:3:600807
# log-likelihood = -98226.47219865971
# iter: 42, time interval: 0:0:3:786711
# log-likelihood = -98220.0507580126
# iter: 43, time interval: 0:0:3:66524
# log-likelihood = -98213.56639384378
# iter: 44, time interval: 0:0:4:285149
# log-likelihood = -98207.11618752197
# iter: 45, time interval: 0:0:3:942188
# log-likelihood = -98200.79454256341
# iter: 46, time interval: 0:0:4:657668
# log-likelihood = -98194.68575373843
# iter: 47, time interval: 0:0:3:798395
# log-likelihood = -98188.85897695742
# iter: 48, time interval: 0:0:3:36151
# log-likelihood = -98183.36576130461
# iter: 49, time interval: 0:0:2:849418
# log-likelihood = -98178.23985574702
# iter: 50, time interval: 0:0:3:7518
# log-likelihood = -98173.49871737996
# iter: 51, time interval: 0:0:3:430605
# log-likelihood = -98169.14605052018
# iter: 52, time interval: 0:0:3:36395
# log-likelihood = -98165.17476433354
# iter: 53, time interval: 0:0:3:485125
# log-likelihood = -98161.5698869218
# iter: 54, time interval: 0:0:3:330027
# log-likelihood = -98158.31115000701
# iter: 55, time interval: 0:0:4:249038
# log-likelihood = -98155.37511316765
# iter: 56, time interval: 0:0:5:404665
# log-likelihood = -98152.73680744186
# iter: 57, time interval: 0:0:4:665696
# log-likelihood = -98150.3709429584
# iter: 58, time interval: 0:0:4:508247
# log-likelihood = -98148.25275360426
# iter: 59, time interval: 0:0:4:49548
# log-likelihood = -98146.35855650596
# iter: 60, time interval: 0:0:3:65322
# log-likelihood = -98144.66609653039
# iter: 61, time interval: 0:0:2:683263
# log-likelihood = -98143.15473379842
# iter: 62, time interval: 0:0:2:868897
# log-likelihood = -98141.80551966163
# iter: 63, time interval: 0:0:3:633477
# log-likelihood = -98140.60119562958
# iter: 64, time interval: 0:0:4:53585
# log-likelihood = -98139.52614088348
# iter: 65, time interval: 0:0:4:136373
# log-likelihood = -98138.56628714985
# iter: 66, time interval: 0:0:4:163041
# log-likelihood = -98137.7090145021
# iter: 67, time interval: 0:0:4:357622
# log-likelihood = -98136.9430377464
# iter: 68, time interval: 0:0:4:15429
# log-likelihood = -98136.25829012999
# iter: 69, time interval: 0:0:4:50780
# log-likelihood = -98135.64580894471
# iter: 70, time interval: 0:0:3:652837
# log-likelihood = -98135.09762600469
# iter: 71, time interval: 0:0:4:617548
# log-likelihood = -98134.60666481637
# iter: 72, time interval: 0:0:4:784673
# log-likelihood = -98134.1666454272
# iter: 73, time interval: 0:0:4:650168
# log-likelihood = -98133.77199735324
# iter: 74, time interval: 0:0:5:535544
# log-likelihood = -98133.41778058515
# iter: 75, time interval: 0:0:5:118284
# log-likelihood = -98133.09961440817
# iter: 76, time interval: 0:0:3:486788
# log-likelihood = -98132.81361360553
# iter: 77, time interval: 0:0:5:430370
# log-likelihood = -98132.5563315213
# iter: 78, time interval: 0:0:4:351792
# log-likelihood = -98132.32470941526
# iter: 79, time interval: 0:0:4:307700
# log-likelihood = -98132.11603153253
# iter: 80, time interval: 0:0:4:885049
# log-likelihood = -98131.92788532427
# iter: 81, time interval: 0:0:3:63989
# log-likelihood = -98131.75812628373
# iter: 82, time interval: 0:0:2:383440
# log-likelihood = -98131.60484689832
# iter: 83, time interval: 0:0:2:272153
# log-likelihood = -98131.46634925781
# iter: 84, time interval: 0:0:2:197643
# log-likelihood = -98131.34112090194
# iter: 85, time interval: 0:0:2:390274
# log-likelihood = -98131.2278135305
# iter: 86, time interval: 0:0:2:31281
# log-likelihood = -98131.12522423879
# iter: 87, time interval: 0:0:2:528419
# log-likelihood = -98131.03227897809
# iter: 88, time interval: 0:0:2:839935
# log-likelihood = -98130.94801797427
# iter: 89, time interval: 0:0:2:545383
# log-likelihood = -98130.87158286918
# iter: 90, time interval: 0:0:2:222567
# log-likelihood = -98130.80220537583
# iter: 91, time interval: 0:0:2:63039
# log-likelihood = -98130.73919726505
# iter: 92, time interval: 0:0:2:148377
# log-likelihood = -98130.68194152163
# iter: 93, time interval: 0:0:2:136653
# log-likelihood = -98130.62988452893
# iter: 94, time interval: 0:0:2:15781
# log-likelihood = -98130.58252915759
# iter: 95, time interval: 0:0:2:86404
# log-likelihood = -98130.53942864932
# iter: 96, time interval: 0:0:2:86944
# log-likelihood = -98130.50018120033
# iter: 97, time interval: 0:0:2:376290
# log-likelihood = -98130.4644251606
# iter: 98, time interval: 0:0:2:965027
# log-likelihood = -98130.43183477574
# iter: 99, time interval: 0:0:2:208594
# log-likelihood = -98130.40211640693
# iter: 100, time interval: 0:0:2:404021
# log-likelihood = -98130.37500517248
# iter: 101, time interval: 0:0:2:112672
# log-likelihood = -98130.35026196168
# iter: 102, time interval: 0:0:2:168263
# log-likelihood = -98130.32767077713
# iter: 103, time interval: 0:0:2:204919
# log-likelihood = -98130.30703636791
# iter: 104, time interval: 0:0:2:386157
# log-likelihood = -98130.28818211962
# iter: 105, time interval: 0:0:2:114998
# log-likelihood = -98130.27094817178
# iter: 106, time interval: 0:0:2:233036
# log-likelihood = -98130.25518973713
# iter: 107, time interval: 0:0:2:81474
# log-likelihood = -98130.2407755995
# iter: 108, time interval: 0:0:2:204956
# log-likelihood = -98130.22758677037
# iter: 109, time interval: 0:0:2:30970
# log-likelihood = -98130.21551528641
# iter: 110, time interval: 0:0:2:121498
# log-likelihood = -98130.20446313216
# iter: 111, time interval: 0:0:2:129742
# log-likelihood = -98130.1943412742
# iter: 112, time interval: 0:0:2:188137
# log-likelihood = -98130.18506879479
# Converge at iteration 113
# iter: 1, time interval: 0:0:5:397068
# log-likelihood = -257074.06608832936
# iter: 2, time interval: 0:0:5:773385
# log-likelihood = -256788.08149678353
# iter: 3, time interval: 0:0:5:675014
# log-likelihood = -256706.62396199175
# iter: 4, time interval: 0:0:5:951732
# log-likelihood = -256660.8421088461
# iter: 5, time interval: 0:0:5:677527
# log-likelihood = -256625.140877395
# iter: 6, time interval: 0:0:6:941293
# log-likelihood = -256593.39415038668
# iter: 7, time interval: 0:0:5:518836
# log-likelihood = -256564.02846348425
# iter: 8, time interval: 0:0:5:773438
# log-likelihood = -256536.76560809347
# iter: 9, time interval: 0:0:5:786548
# log-likelihood = -256511.61114947227
# iter: 10, time interval: 0:0:6:212155
# log-likelihood = -256488.4944749872
# iter: 11, time interval: 0:0:5:537790
# log-likelihood = -256467.18449701893
# iter: 12, time interval: 0:0:5:485034
# log-likelihood = -256447.33649632568
# iter: 13, time interval: 0:0:5:574549
# log-likelihood = -256428.58050809172
# iter: 14, time interval: 0:0:5:719183
# log-likelihood = -256410.5966924822
# iter: 15, time interval: 0:0:5:868741
# log-likelihood = -256393.15633842864
# iter: 16, time interval: 0:0:5:534694
# log-likelihood = -256376.12999999608
# iter: 17, time interval: 0:0:7:169414
# log-likelihood = -256359.4738573521
# iter: 18, time interval: 0:0:5:770244
# log-likelihood = -256343.2059919549
# iter: 19, time interval: 0:0:6:191586
# log-likelihood = -256327.38117323714
# iter: 20, time interval: 0:0:6:752440
# log-likelihood = -256312.06916179464
# iter: 21, time interval: 0:0:6:178119
# log-likelihood = -256297.33866156425
# iter: 22, time interval: 0:0:6:68526
# log-likelihood = -256283.2471426026
# iter: 23, time interval: 0:0:6:134177
# log-likelihood = -256269.83569753016
# iter: 24, time interval: 0:0:6:130701
# log-likelihood = -256257.12767114706
# iter: 25, time interval: 0:0:6:471671
# log-likelihood = -256245.12978301503
# iter: 26, time interval: 0:0:5:568084
# log-likelihood = -256233.83465308067
# iter: 27, time interval: 0:0:4:637172
# log-likelihood = -256223.22390610792
# iter: 28, time interval: 0:0:7:157662
# log-likelihood = -256213.27129354043
# iter: 29, time interval: 0:0:6:234896
# log-likelihood = -256203.9454942691
# iter: 30, time interval: 0:0:5:611632
# log-likelihood = -256195.2124266513
# iter: 31, time interval: 0:0:5:487101
# log-likelihood = -256187.0370242974
# iter: 32, time interval: 0:0:6:57317
# log-likelihood = -256179.38450495093
# iter: 33, time interval: 0:0:6:655232
# log-likelihood = -256172.22120451156
# iter: 34, time interval: 0:0:6:893198
# log-likelihood = -256165.51506602703
# iter: 35, time interval: 0:0:6:203097
# log-likelihood = -256159.2358743283
# iter: 36, time interval: 0:0:7:126252
# log-likelihood = -256153.3553174728
# iter: 37, time interval: 0:0:8:295282
# log-likelihood = -256147.846941357
# iter: 38, time interval: 0:0:10:763122
# log-likelihood = -256142.68604747168
# iter: 39, time interval: 0:0:9:768963
# log-likelihood = -256137.8495682915
# iter: 40, time interval: 0:0:9:724386
# log-likelihood = -256133.31594169044
# iter: 41, time interval: 0:0:9:888739
# log-likelihood = -256129.06499570684
# iter: 42, time interval: 0:0:9:826137
# log-likelihood = -256125.07784797478
# iter: 43, time interval: 0:0:9:122908
# log-likelihood = -256121.33681981775
# iter: 44, time interval: 0:0:7:854063
# log-likelihood = -256117.82536277355
# iter: 45, time interval: 0:0:13:172314
# log-likelihood = -256114.5279945534
# iter: 46, time interval: 0:0:8:751969
# log-likelihood = -256111.4302415539
# iter: 47, time interval: 0:0:9:685964
# log-likelihood = -256108.5185855967
# iter: 48, time interval: 0:0:9:54556
# log-likelihood = -256105.78041325443
# iter: 49, time interval: 0:0:8:422773
# log-likelihood = -256103.2039667598
# iter: 50, time interval: 0:0:10:46023
# log-likelihood = -256100.77829599744
# iter: 51, time interval: 0:0:5:299302
# log-likelihood = -256098.49321143542
# iter: 52, time interval: 0:0:6:95549
# log-likelihood = -256096.3392380663
# iter: 53, time interval: 0:0:8:115024
# log-likelihood = -256094.3075705452
# iter: 54, time interval: 0:0:7:772057
# log-likelihood = -256092.39002974454
# iter: 55, time interval: 0:0:5:715191
# log-likelihood = -256090.5790209406
# iter: 56, time interval: 0:0:6:189457
# log-likelihood = -256088.8674938101
# iter: 57, time interval: 0:0:6:153066
# log-likelihood = -256087.24890437126
# iter: 58, time interval: 0:0:5:941131
# log-likelihood = -256085.7171789537
# iter: 59, time interval: 0:0:5:991064
# log-likelihood = -256084.26668024156
# iter: 60, time interval: 0:0:5:858330
# log-likelihood = -256082.89217539097
# iter: 61, time interval: 0:0:6:535451
# log-likelihood = -256081.58880619612
# iter: 62, time interval: 0:0:6:74714
# log-likelihood = -256080.35206125068
# iter: 63, time interval: 0:0:6:403534
# log-likelihood = -256079.17775003499
# iter: 64, time interval: 0:0:6:980510
# log-likelihood = -256078.06197884333
# iter: 65, time interval: 0:0:6:372472
# log-likelihood = -256077.00112846112
# iter: 66, time interval: 0:0:6:614437
# log-likelihood = -256075.99183349343
# iter: 67, time interval: 0:0:6:873963
# log-likelihood = -256075.03096324517
# iter: 68, time interval: 0:0:6:350076
# log-likelihood = -256074.11560405412
# iter: 69, time interval: 0:0:5:914037
# log-likelihood = -256073.24304297878
# iter: 70, time interval: 0:0:6:98778
# log-likelihood = -256072.41075274616
# iter: 71, time interval: 0:0:5:760839
# log-likelihood = -256071.61637786904
# iter: 72, time interval: 0:0:5:659383
# log-likelihood = -256070.85772184524
# iter: 73, time interval: 0:0:5:849306
# log-likelihood = -256070.13273535887
# iter: 74, time interval: 0:0:7:396268
# log-likelihood = -256069.43950540386
# iter: 75, time interval: 0:0:5:522273
# log-likelihood = -256068.77624526105
# iter: 76, time interval: 0:0:6:411372
# log-likelihood = -256068.1412852592
# iter: 77, time interval: 0:0:6:153500
# log-likelihood = -256067.53306425875
# iter: 78, time interval: 0:0:6:364182
# log-likelihood = -256066.95012180076
# iter: 79, time interval: 0:0:6:455959
# log-likelihood = -256066.39109086647
# iter: 80, time interval: 0:0:6:163526
# log-likelihood = -256065.85469119955
# iter: 81, time interval: 0:0:5:891199
# log-likelihood = -256065.3397231448
# iter: 82, time interval: 0:0:5:808436
# log-likelihood = -256064.8450619614
# iter: 83, time interval: 0:0:6:887264
# log-likelihood = -256064.36965257258
# iter: 84, time interval: 0:0:6:862131
# log-likelihood = -256063.91250471675
# iter: 85, time interval: 0:0:6:489019
# log-likelihood = -256063.47268846628
# iter: 86, time interval: 0:0:5:840064
# log-likelihood = -256063.04933008607
# iter: 87, time interval: 0:0:6:502063
# log-likelihood = -256062.64160820266
# iter: 88, time interval: 0:0:6:5383
# log-likelihood = -256062.24875026048
# iter: 89, time interval: 0:0:6:101510
# log-likelihood = -256061.87002924178
# iter: 90, time interval: 0:0:6:452736
# log-likelihood = -256061.5047606281
# iter: 91, time interval: 0:0:5:950085
# log-likelihood = -256061.15229958587
# iter: 92, time interval: 0:0:6:342606
# log-likelihood = -256060.81203835705
# iter: 93, time interval: 0:0:5:902487
# log-likelihood = -256060.48340383946
# iter: 94, time interval: 0:0:6:81771
# log-likelihood = -256060.16585534113
# iter: 95, time interval: 0:0:7:834028
# log-likelihood = -256059.85888249602
# iter: 96, time interval: 0:0:4:817287
# log-likelihood = -256059.56200332753
# iter: 97, time interval: 0:0:5:238157
# log-likelihood = -256059.2747624497
# iter: 98, time interval: 0:0:3:685762
# log-likelihood = -256058.9967293937
# iter: 99, time interval: 0:0:3:756024
# log-likelihood = -256058.72749705205
# iter: 100, time interval: 0:0:3:671857
# log-likelihood = -256058.46668023051
# iter: 101, time interval: 0:0:3:610825
# log-likelihood = -256058.21391429877
# iter: 102, time interval: 0:0:3:408914
# log-likelihood = -256057.9688539345
# iter: 103, time interval: 0:0:3:677849
# log-likelihood = -256057.73117195256
# iter: 104, time interval: 0:0:3:593332
# log-likelihood = -256057.5005582121
# iter: 105, time interval: 0:0:3:593596
# log-likelihood = -256057.27671859873
# iter: 106, time interval: 0:0:4:89577
# log-likelihood = -256057.05937407215
# iter: 107, time interval: 0:0:3:578041
# log-likelihood = -256056.8482597793
# iter: 108, time interval: 0:0:4:178780
# log-likelihood = -256056.64312422337
# iter: 109, time interval: 0:0:3:672008
# log-likelihood = -256056.44372848858
# iter: 110, time interval: 0:0:3:631943
# log-likelihood = -256056.24984551448
# iter: 111, time interval: 0:0:3:393000
# log-likelihood = -256056.06125941733
# iter: 112, time interval: 0:0:3:424053
# log-likelihood = -256055.8777648543
# iter: 113, time interval: 0:0:3:439905
# log-likelihood = -256055.6991664285
# iter: 114, time interval: 0:0:3:493510
# log-likelihood = -256055.5252781315
# iter: 115, time interval: 0:0:3:424353
# log-likelihood = -256055.35592282077
# iter: 116, time interval: 0:0:3:505352
# log-likelihood = -256055.19093172913
# iter: 117, time interval: 0:0:3:527652
# log-likelihood = -256055.03014400543
# iter: 118, time interval: 0:0:3:894005
# log-likelihood = -256054.8734062827
# iter: 119, time interval: 0:0:3:593320
# log-likelihood = -256054.720572273
# iter: 120, time interval: 0:0:3:709862
# log-likelihood = -256054.57150238674
# iter: 121, time interval: 0:0:3:572036
# log-likelihood = -256054.426063375
# iter: 122, time interval: 0:0:3:408642
# log-likelihood = -256054.28412799304
# iter: 123, time interval: 0:0:3:430464
# log-likelihood = -256054.14557468443
# iter: 124, time interval: 0:0:3:393249
# log-likelihood = -256054.01028728255
# iter: 125, time interval: 0:0:3:424332
# log-likelihood = -256053.8781547315
# iter: 126, time interval: 0:0:3:393066
# log-likelihood = -256053.7490708216
# iter: 127, time interval: 0:0:3:455576
# log-likelihood = -256053.62293394093
# iter: 128, time interval: 0:0:3:462181
# log-likelihood = -256053.4996468415
# iter: 129, time interval: 0:0:3:408509
# log-likelihood = -256053.37911641801
# iter: 130, time interval: 0:0:3:486697
# log-likelihood = -256053.2612535001
# iter: 131, time interval: 0:0:3:431022
# log-likelihood = -256053.14597265556
# iter: 132, time interval: 0:0:3:386982
# log-likelihood = -256053.0331920051
# iter: 133, time interval: 0:0:3:377793
# log-likelihood = -256052.9228330472
# iter: 134, time interval: 0:0:3:424009
# log-likelihood = -256052.81482049302
# iter: 135, time interval: 0:0:3:392825
# log-likelihood = -256052.70908210988
# iter: 136, time interval: 0:0:3:377737
# log-likelihood = -256052.6055485741
# iter: 137, time interval: 0:0:3:371148
# log-likelihood = -256052.50415333087
# iter: 138, time interval: 0:0:3:431260
# log-likelihood = -256052.40483246275
# iter: 139, time interval: 0:0:3:386737
# log-likelihood = -256052.30752456453
# iter: 140, time interval: 0:0:3:377491
# log-likelihood = -256052.21217062502
# iter: 141, time interval: 0:0:3:361612
# log-likelihood = -256052.11871391544
# iter: 142, time interval: 0:0:3:386450
# log-likelihood = -256052.02709988295
# iter: 143, time interval: 0:0:3:377821
# log-likelihood = -256051.93727605094
# iter: 144, time interval: 0:0:3:393520
# log-likelihood = -256051.84919192316
# iter: 145, time interval: 0:0:3:424438
# log-likelihood = -256051.76279889405
# iter: 146, time interval: 0:0:3:392734
# log-likelihood = -256051.67805016306
# iter: 147, time interval: 0:0:3:709141
# log-likelihood = -256051.59490065358
# iter: 148, time interval: 0:0:3:724152
# log-likelihood = -256051.51330693584
# iter: 149, time interval: 0:0:3:726888
# log-likelihood = -256051.43322715408
# iter: 150, time interval: 0:0:4:123194
# log-likelihood = -256051.35462095714
# iter: 151, time interval: 0:0:3:509207
# log-likelihood = -256051.2774494323
# iter: 152, time interval: 0:0:3:624820
# log-likelihood = -256051.20167504303
# iter: 153, time interval: 0:0:3:515580
# log-likelihood = -256051.1272615697
# iter: 154, time interval: 0:0:3:440188
# log-likelihood = -256051.0541740524
# iter: 155, time interval: 0:0:3:408908
# log-likelihood = -256050.98237873797
# iter: 156, time interval: 0:0:3:393428
# log-likelihood = -256050.91184302833
# iter: 157, time interval: 0:0:3:408431
# log-likelihood = -256050.84253543214
# iter: 158, time interval: 0:0:3:439863
# log-likelihood = -256050.77442551835
# iter: 159, time interval: 0:0:3:393482
# log-likelihood = -256050.70748387242
# iter: 160, time interval: 0:0:3:377980
# log-likelihood = -256050.64168205412
# iter: 161, time interval: 0:0:3:386502
# log-likelihood = -256050.5769925576
# iter: 162, time interval: 0:0:3:477485
# log-likelihood = -256050.5133887736
# iter: 163, time interval: 0:0:3:408984
# log-likelihood = -256050.4508449529
# iter: 164, time interval: 0:0:3:393087
# log-likelihood = -256050.38933617185
# iter: 165, time interval: 0:0:3:424575
# log-likelihood = -256050.32883829944
# iter: 166, time interval: 0:0:3:525115
# log-likelihood = -256050.26932796597
# iter: 167, time interval: 0:0:3:524806
# log-likelihood = -256050.21078253278
# iter: 168, time interval: 0:0:3:709667
# log-likelihood = -256050.1531800638
# iter: 169, time interval: 0:0:3:424304
# log-likelihood = -256050.0964992984
# iter: 170, time interval: 0:0:3:578330
# log-likelihood = -256050.04071962513
# iter: 171, time interval: 0:0:3:378023
# log-likelihood = -256049.98582105676
# iter: 172, time interval: 0:0:3:370703
# log-likelihood = -256049.93178420665
# iter: 173, time interval: 0:0:3:577759
# log-likelihood = -256049.878590266
# iter: 174, time interval: 0:0:3:609249
# log-likelihood = -256049.8262209822
# iter: 175, time interval: 0:0:3:446692
# log-likelihood = -256049.77465863765
# iter: 176, time interval: 0:0:3:440151
# log-likelihood = -256049.72388603055
# iter: 177, time interval: 0:0:3:377763
# log-likelihood = -256049.6738864557
# iter: 178, time interval: 0:0:3:587325
# log-likelihood = -256049.6246436858
# iter: 179, time interval: 0:0:3:477648
# log-likelihood = -256049.57614195484
# iter: 180, time interval: 0:0:3:524518
# log-likelihood = -256049.52836594117
# iter: 181, time interval: 0:0:3:509551
# log-likelihood = -256049.4813007514
# iter: 182, time interval: 0:0:3:424964
# log-likelihood = -256049.43493190527
# iter: 183, time interval: 0:0:3:430963
# log-likelihood = -256049.38924532125
# iter: 184, time interval: 0:0:3:424152
# log-likelihood = -256049.34422730224
# iter: 185, time interval: 0:0:3:439850
# log-likelihood = -256049.29986452233
# iter: 186, time interval: 0:0:3:408909
# log-likelihood = -256049.25614401395
# iter: 187, time interval: 0:0:3:393585
# log-likelihood = -256049.2130531553
# iter: 188, time interval: 0:0:3:424758
# log-likelihood = -256049.17057965894
# iter: 189, time interval: 0:0:3:393293
# log-likelihood = -256049.12871156028
# iter: 190, time interval: 0:0:3:440103
# log-likelihood = -256049.0874372065
# iter: 191, time interval: 0:0:3:392639
# log-likelihood = -256049.04674524636
# iter: 192, time interval: 0:0:3:392949
# log-likelihood = -256049.00662462017
# iter: 193, time interval: 0:0:3:424399
# log-likelihood = -256048.96706455003
# iter: 194, time interval: 0:0:3:424906
# log-likelihood = -256048.9280545307
# iter: 195, time interval: 0:0:3:439849
# log-likelihood = -256048.88958432057
# iter: 196, time interval: 0:0:3:361728
# log-likelihood = -256048.85164393354
# iter: 197, time interval: 0:0:3:440205
# log-likelihood = -256048.81422363032
# iter: 198, time interval: 0:0:3:462571
# log-likelihood = -256048.77731391092
# iter: 199, time interval: 0:0:3:509394
# log-likelihood = -256048.7409055067
# iter: 200, time interval: 0:0:3:509537
# log-likelihood = -256048.70498937368
# iter: 201, time interval: 0:0:3:493507
# log-likelihood = -256048.66955668502
# iter: 202, time interval: 0:0:3:424369
# log-likelihood = -256048.63459882428
# iter: 203, time interval: 0:0:3:424317
# log-likelihood = -256048.60010737943
# iter: 204, time interval: 0:0:3:562531
# log-likelihood = -256048.5660741361
# iter: 205, time interval: 0:0:3:487291
# log-likelihood = -256048.53249107173
# iter: 206, time interval: 0:0:3:430730
# log-likelihood = -256048.4993503499
# iter: 207, time interval: 0:0:3:555617
# log-likelihood = -256048.46664431464
# iter: 208, time interval: 0:0:3:462125
# log-likelihood = -256048.4343654851
# iter: 209, time interval: 0:0:3:371212
# log-likelihood = -256048.40250655028
# iter: 210, time interval: 0:0:3:462501
# log-likelihood = -256048.37106036418
# iter: 211, time interval: 0:0:3:524595
# log-likelihood = -256048.34001994104
# iter: 212, time interval: 0:0:3:593768
# log-likelihood = -256048.30937845047
# iter: 213, time interval: 0:0:3:524771
# log-likelihood = -256048.27912921316
# iter: 214, time interval: 0:0:3:424204
# log-likelihood = -256048.2492656966
# iter: 215, time interval: 0:0:3:540114
# log-likelihood = -256048.21978151068
# iter: 216, time interval: 0:0:3:393681
# log-likelihood = -256048.19067040383
# iter: 217, time interval: 0:0:3:446508
# log-likelihood = -256048.16192625955
# iter: 218, time interval: 0:0:3:508747
# log-likelihood = -256048.1335430917
# iter: 219, time interval: 0:0:3:386868
# log-likelihood = -256048.10551504188
# iter: 220, time interval: 0:0:3:393674
# log-likelihood = -256048.07783637528
# iter: 221, time interval: 0:0:3:362223
# log-likelihood = -256048.05050147758
# iter: 222, time interval: 0:0:3:392742
# log-likelihood = -256048.02350485185
# iter: 223, time interval: 0:0:3:408287
# log-likelihood = -256047.99684111486
# iter: 224, time interval: 0:0:3:355732
# log-likelihood = -256047.97050499474
# iter: 225, time interval: 0:0:3:455808
# log-likelihood = -256047.94449132736
# iter: 226, time interval: 0:0:3:393050
# log-likelihood = -256047.91879505405
# iter: 227, time interval: 0:0:3:377382
# log-likelihood = -256047.89341121845
# iter: 228, time interval: 0:0:3:377668
# log-likelihood = -256047.868334964
# iter: 229, time interval: 0:0:3:370543
# log-likelihood = -256047.84356153154
# iter: 230, time interval: 0:0:3:408566
# log-likelihood = -256047.81908625623
# iter: 231, time interval: 0:0:3:377600
# log-likelihood = -256047.79490456593
# iter: 232, time interval: 0:0:3:393814
# log-likelihood = -256047.7710119784
# iter: 233, time interval: 0:0:3:355257
# log-likelihood = -256047.74740409883
# iter: 234, time interval: 0:0:3:408341
# log-likelihood = -256047.72407661815
# iter: 235, time interval: 0:0:3:377226
# log-likelihood = -256047.7010253107
# iter: 236, time interval: 0:0:3:362176
# log-likelihood = -256047.67824603195
# iter: 237, time interval: 0:0:3:408341
# log-likelihood = -256047.65573471691
# iter: 238, time interval: 0:0:3:424229
# log-likelihood = -256047.63348737772
# iter: 239, time interval: 0:0:3:440289
# log-likelihood = -256047.6115001023
# iter: 240, time interval: 0:0:3:393170
# log-likelihood = -256047.5897690521
# iter: 241, time interval: 0:0:3:376994
# log-likelihood = -256047.5682904605
# iter: 242, time interval: 0:0:3:386425
# log-likelihood = -256047.54706063122
# iter: 243, time interval: 0:0:3:378065
# log-likelihood = -256047.52607593636
# iter: 244, time interval: 0:0:3:378107
# log-likelihood = -256047.50533281508
# iter: 245, time interval: 0:0:3:424236
# log-likelihood = -256047.48482777187
# iter: 246, time interval: 0:0:3:354958
# log-likelihood = -256047.46455737506
# iter: 247, time interval: 0:0:3:377556
# log-likelihood = -256047.44451825542
# iter: 248, time interval: 0:0:3:440415
# log-likelihood = -256047.42470710463
# iter: 249, time interval: 0:0:3:377535
# log-likelihood = -256047.4051206739
# iter: 250, time interval: 0:0:3:424220
# log-likelihood = -256047.38575577267
# iter: 251, time interval: 0:0:3:393237
# log-likelihood = -256047.36660926734
# iter: 252, time interval: 0:0:3:377394
# log-likelihood = -256047.3476780798
# iter: 253, time interval: 0:0:3:370871
# log-likelihood = -256047.3289591864
# iter: 254, time interval: 0:0:3:431006
# log-likelihood = -256047.31044961652
# iter: 255, time interval: 0:0:3:355721
# log-likelihood = -256047.29214645174
# iter: 256, time interval: 0:0:3:361924
# log-likelihood = -256047.27404682434
# iter: 257, time interval: 0:0:3:386190
# log-likelihood = -256047.25614791643
# iter: 258, time interval: 0:0:3:430592
# log-likelihood = -256047.2384469587
# iter: 259, time interval: 0:0:3:386888
# log-likelihood = -256047.22094122946
# iter: 260, time interval: 0:0:3:462466
# log-likelihood = -256047.20362805366
# iter: 261, time interval: 0:0:3:471196
# log-likelihood = -256047.1865048018
# iter: 262, time interval: 0:0:3:386461
# log-likelihood = -256047.16956888913
# iter: 263, time interval: 0:0:3:408860
# log-likelihood = -256047.15281777433
# iter: 264, time interval: 0:0:3:377250
# log-likelihood = -256047.136248959
# iter: 265, time interval: 0:0:3:624807
# log-likelihood = -256047.11985998662
# iter: 266, time interval: 0:0:3:393227
# log-likelihood = -256047.1036484416
# iter: 267, time interval: 0:0:3:393515
# log-likelihood = -256047.0876119487
# iter: 268, time interval: 0:0:3:371009
# log-likelihood = -256047.0717481716
# iter: 269, time interval: 0:0:3:376958
# log-likelihood = -256047.05605481283
# iter: 270, time interval: 0:0:3:424410
# log-likelihood = -256047.04052961266
# iter: 271, time interval: 0:0:3:462613
# log-likelihood = -256047.02517034806
# iter: 272, time interval: 0:0:3:778357
# log-likelihood = -256047.0099748324
# iter: 273, time interval: 0:0:3:640076
# log-likelihood = -256046.99494091456
# iter: 274, time interval: 0:0:3:455581
# log-likelihood = -256046.9800664781
# iter: 275, time interval: 0:0:3:392991
# log-likelihood = -256046.9653494408
# iter: 276, time interval: 0:0:3:408925
# log-likelihood = -256046.95078775368
# iter: 277, time interval: 0:0:3:377890
# log-likelihood = -256046.9363794006
# iter: 278, time interval: 0:0:3:440157
# log-likelihood = -256046.9221223976
# iter: 279, time interval: 0:0:3:393289
# log-likelihood = -256046.9080147921
# iter: 280, time interval: 0:0:3:377315
# log-likelihood = -256046.89405466238
# iter: 281, time interval: 0:0:3:370950
# log-likelihood = -256046.88024011708
# iter: 282, time interval: 0:0:3:431157
# log-likelihood = -256046.86656929448
# iter: 283, time interval: 0:0:3:471803
# log-likelihood = -256046.85304036195
# iter: 284, time interval: 0:0:3:539850
# log-likelihood = -256046.8396515155
# iter: 285, time interval: 0:0:3:531085
# log-likelihood = -256046.8264009791
# iter: 286, time interval: 0:0:3:440053
# log-likelihood = -256046.81328700422
# iter: 287, time interval: 0:0:3:377980
# log-likelihood = -256046.8003078693
# iter: 288, time interval: 0:0:3:393457
# log-likelihood = -256046.78746187923
# iter: 289, time interval: 0:0:3:386720
# log-likelihood = -256046.77474736492
# iter: 290, time interval: 0:0:3:409201
# log-likelihood = -256046.76216268275
# iter: 291, time interval: 0:0:3:361734
# log-likelihood = -256046.749706214
# iter: 292, time interval: 0:0:3:424793
# log-likelihood = -256046.73737636476
# iter: 293, time interval: 0:0:3:408957
# log-likelihood = -256046.72517156487
# iter: 294, time interval: 0:0:3:425033
# log-likelihood = -256046.7130902681
# iter: 295, time interval: 0:0:3:361721
# log-likelihood = -256046.7011309514
# iter: 296, time interval: 0:0:3:339312
# log-likelihood = -256046.68929211443
# iter: 297, time interval: 0:0:3:361886
# log-likelihood = -256046.6775722793
# iter: 298, time interval: 0:0:3:424941
# log-likelihood = -256046.6659699901
# iter: 299, time interval: 0:0:3:393713
# log-likelihood = -256046.6544838125
# iter: 300, time interval: 0:0:3:355583
# log-likelihood = -256046.64311233346
# iter: 301, time interval: 0:0:3:361858
# log-likelihood = -256046.6318541607
# iter: 302, time interval: 0:0:3:540209
# log-likelihood = -256046.62070792227
# iter: 303, time interval: 0:0:3:377618
# log-likelihood = -256046.60967226652
# iter: 304, time interval: 0:0:3:386804
# log-likelihood = -256046.5987458616
# iter: 305, time interval: 0:0:3:462720
# log-likelihood = -256046.58792739466
# iter: 306, time interval: 0:0:3:393584
# log-likelihood = -256046.57721557235
# iter: 307, time interval: 0:0:3:377310
# log-likelihood = -256046.56660911982
# iter: 308, time interval: 0:0:3:370922
# log-likelihood = -256046.5561067807
# iter: 309, time interval: 0:0:3:340120
# log-likelihood = -256046.5457073166
# iter: 310, time interval: 0:0:3:409299
# log-likelihood = -256046.53540950696
# iter: 311, time interval: 0:0:3:361927
# log-likelihood = -256046.5252121487
# iter: 312, time interval: 0:0:3:393404
# log-likelihood = -256046.51511405598
# iter: 313, time interval: 0:0:3:393272
# log-likelihood = -256046.50511405955
# Converge at iteration 314

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15,15))
ax_list = [ax1, ax2, ax3]
i = 1
# FIRST ROW: display image segment
for rand_em_img, ax in zip(rand_em_img_list, ax_list):
    ax.imshow(rand_em_img, cmap = 'gray')
    ax.set_title('[Image {}] Segmentation by EM'.format(i))
    # Set x-axis, y-axis
    ax.axes.set_xlabel('x-coordinate')
    ax.axes.set_ylabel('y-coordinate')
    i += 1;

# Make a nice layout
plt.tight_layout();
fig.savefig('em_rand_init.pdf')
